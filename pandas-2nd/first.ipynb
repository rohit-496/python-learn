# %%
import numpy as np
import pandas as pd

# %%
labels = {"a","b","c"} #label are known as indices
my_list = [10,20,40]
arr =np.array(my_list)
d ={1:10,2:20, 3:30}

# %%
pd.Series(my_list) #series is vertical but list is horizontal
# Out:
# 0    10
# 1    20
# 2    40
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    40
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    40
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# combining two or more series can make it a dataframe

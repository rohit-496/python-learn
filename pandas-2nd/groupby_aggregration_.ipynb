# %%
import pandas as pd

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2026-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
cat = df.groupby("Category")["Sales"].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
for i, v in cat:
    print(i)
    print(v)
# Out:
# A
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
cat2 = df.groupby(["Category","Store"])["Sales"].sum()
cat2
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
#Agrregation: Aggregate all rows value of column and give one value

# %%
df["Sales"].mean
'''mean medain mode min max count.....'''

# %%
df["Sales"].agg(["mean","count"])
#count calculates how many valid data are there in a column
# Out:
# mean     187.5
# count      8.0
# Name: Sales, dtype: float64

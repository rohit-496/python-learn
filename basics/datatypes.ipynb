# %% [markdown]
# Datatypes

# %% [markdown]
# Datatypes are the classification of data which tell the compiler or interpreter  hwo the programmer uses the data

# %% [markdown]
# They determine the types of operations to be performed on the data

# %% [markdown]
# Basic Data Types
# 1. int
# 2. float
# 3. Bool
# 4. str

# %% [markdown]
# Advanced Dtypes/ Data Structure
# 1. List
# 2. Tuples
# 3. Sets
# 4. Dictionaries

# %%
name = "Rohit"
age = 35
print(name,age )
# Out:
# Rohit 35

# %%
# boolean datatype
is_true = True
type (is_true)
# Out:
# bool

# %%
is_true = bool()
is_true ## default value is false
# Out:
# False

# %%
## common errors
result = "hello" + str(5)

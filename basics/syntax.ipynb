# %% [markdown]
# Syntax refers toi the set of rules that defines how the code needs to be structured. Syntax is all about the correct arrangement of words and symbols in a code..

# %% [markdown]
# Semantics refers to the meaning or the interpretation of symbols,characters and commands in a language. It is about what the code is supposed to  do when it runs.

# %%
## Basic syntax in python
## Python is case sensitive

# %% [markdown]
# Indentation in python defines the hierarchy of the code. Unlike many othe rprogramming languages that use {} braces to delimit the blocks of code. Python uses indentation to determine the grouping of statements.

# %%
##Line continuation
total = 1+2+3+\
4
print(total)
# Out:
# 10

# %%
#Multiple statements in a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
#Understand Semantics in Python
#variable assignment
age = 32 #python understands the datatype in runtime

# %%
type(age)
# Out:
# int

# %%
#code example of indentation
if True:
    print("Correct Identation")
    if False:
        print("This not print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Identation
# This will print
# Outside the if block

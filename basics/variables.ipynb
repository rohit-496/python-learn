# %% [markdown]
# Variables are fundamental elements in programming used to store data that can be referenced manipulated in a program. In python, variables are created when you assign a value to them, and they donot need explicit declaration to reserve memeory space

# %%
age  = 32 
height = 5.7 
name = "rohit"
is_student = True

print("Age:",age)
print("Height:" ,height)
print("Name:",name)
# Out:
# Age: 32
# Height: 5.7
# Name: rohit

# %%
## Rules for naming variable
## Variable should be descriptive
## They must start with letter or an '_' and contains latter, number and underscores
## variables names are case sensitive

first_name = "Rohit"
last_name = "Nyaupane"

# %%
##Invalid names
# 2age = 30
# first-name = "Rohit"
# @name = "Rohit"

## case sensitivity 
name = "Rohit"
Name = "Nyaupane"
# Out:
# False

# %%
## Variable Types
## Python is dynamically typed, type of a variable is determined at runtime
age = 25
name = "rohit"

print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Typechecking and conversion
type(height)
# Out:
# float

# %%
age = 25
print(type(age))

age_str = str(age)
print (type(age_str))
print(age_str)
# Out:
# <class 'int'>
# <class 'str'>
# 25

# %%
age = "25"
print(type(int(age)))
# Out:
# <class 'int'>
# '25'

# %%
#Dynamic Typing
## Python allows the type of variable to change as the program executes
var = 10 
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>

# %% [markdown]
# Arithmetic operators

# %%
a = 10 
b = 5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**2)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100

# %% [markdown]
# Comparision operators

# %%
a = 10
b = 10
result = (a==b)
result
# Out:
# True

# %%
a != b
# Out:
# False

# %% [markdown]
# Likewise >, <, >=, <=

# %%
X= True
Y = True
Z = False
print ( X and Y)
print(X and Z)
# Out:
# True
# False

# %%
X  = False
not X
# Out:
# True
